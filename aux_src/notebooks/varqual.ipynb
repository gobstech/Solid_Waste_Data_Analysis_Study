# %%
regioes_coleta = ['Centro', 'Zona Leste', 'Zona Norte', 'Zona Oeste', 'Zona Sul']
regioes_coleta
# Out:
# ['Centro', 'Zona Leste', 'Zona Norte', 'Zona Oeste', 'Zona Sul']

# %%
tipos_residuos = ['Orgânico', 'Perigoso', 'Reciclável', 'Rejeito']
tipos_residuos
# Out:
# ['Orgânico', 'Perigoso', 'Reciclável', 'Rejeito']

# %%
origens_residuos = ['Comercial', 'Industrial', 'Residencial', 'Serviços de Saúde']
origens_residuos
# Out:
# ['Comercial', 'Industrial', 'Residencial', 'Serviços de Saúde']

# %%
metodos_destinacao = ['Aterro Sanitário', 'Compostagem', 'Incineração', 'Reciclagem']
metodos_destinacao
# Out:
# ['Aterro Sanitário', 'Compostagem', 'Incineração', 'Reciclagem']
