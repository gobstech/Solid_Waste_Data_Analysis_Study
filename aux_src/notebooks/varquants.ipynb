# %%
var_quants = ['Massa Coleta (kg)', 'Densidade do resíduo (kg/m³)', 'Umidade do Resíduo (%)', 'Distância de Destinação (km)', 'Custo de Coleta do Transporte (R$/Ton)', 'Índice de Reciclabilidade (%)', 'Poder Calorífico (MJ/kg)']
